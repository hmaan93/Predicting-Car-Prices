# %%
import pandas as pd

# %%
cars=pd.read_csv('imports-85.data.txt', header=None, names=["symbolizing", "normalized_losses", "make", "fuel_type", "asipiration", "num_doors", "body_style", "drive_wheels", "engine_location", "wheel_base", "length", "width", "height", "curb_weight", "engine_type", "num_cylinders", "engine_size", "fuel_system","bore","stroke", "compression_ratio", "horsepower", "peak_rpm", "city_mpg", "highway_mpg", "price"])

# %%
print(cars.head())
# Out:
#    symbolizing normalized_losses         make fuel_type asipiration num_doors  \
# 0            3                 ?  alfa-romero       gas         std       two
# 1            3                 ?  alfa-romero       gas         std       two
# 2            1                 ?  alfa-romero       gas         std       two
# 3            2               164         audi       gas         std      four
# 4            2               164         audi       gas         std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...    engine_size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
print(cars.shape)
# Out:
# (205, 26)

# %%
import numpy as np
cars=cars.replace(to_replace="?", value=np.nan)

# %%
print(cars.head())
# Out:
#    symbolizing normalized_losses         make fuel_type asipiration num_doors  \
# 0            3               NaN  alfa-romero       gas         std       two
# 1            3               NaN  alfa-romero       gas         std       two
# 2            1               NaN  alfa-romero       gas         std       two
# 3            2               164         audi       gas         std      four
# 4            2               164         audi       gas         std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...    engine_size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
print(cars.dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-16bd5eac3eb5> in <module>()
# ----> 1 print(cars.dtype)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
cars.dtypes
cars.head()
# Out:
#    symbolizing normalized_losses         make fuel_type asipiration num_doors  \
# 0            3               NaN  alfa-romero       gas         std       two
# 1            3               NaN  alfa-romero       gas         std       two
# 2            1               NaN  alfa-romero       gas         std       two
# 3            2               164         audi       gas         std      four
# 4            2               164         audi       gas         std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...    engine_size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
cars.dtypes
# Out:
# dtype('float64')

# %%
cars=cars['normalized_losses'].astype(float)

# %%
cars.dtypes
# Out:
# dtype('float64')

# %%
cars=pd.read_csv('imports-85.data.txt', header=None, names=["symbolizing", "normalized_losses", "make", "fuel_type", "asipiration", "num_doors", "body_style", "drive_wheels", "engine_location", "wheel_base", "length", "width", "height", "curb_weight", "engine_type", "num_cylinders", "engine_size", "fuel_system","bore","stroke", "compression_ratio", "horsepower", "peak_rpm", "city_mpg", "highway_mpg", "price"])

# %%
cars.head()
# Out:
#    symbolizing normalized_losses         make fuel_type asipiration num_doors  \
# 0            3                 ?  alfa-romero       gas         std       two
# 1            3                 ?  alfa-romero       gas         std       two
# 2            1                 ?  alfa-romero       gas         std       two
# 3            2               164         audi       gas         std      four
# 4            2               164         audi       gas         std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...    engine_size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
cars.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1bcd02486e15> in <module>()
# ----> 1 cars.dtype()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
cars.dtypes
# Out:
# symbolizing            int64
# normalized_losses     object
# make                  object
# fuel_type             object
# asipiration           object
# num_doors             object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_cylinders         object
# engine_size            int64
# fuel_system           object
# bore                  object
# stroke                object
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highway_mpg            int64
# price                 object
# dtype: object

# %%
import numpy as np
cars=cars.replace(to_replace='?', value=np.nan)

# %%
cars.head()
# Out:
#    symbolizing normalized_losses         make fuel_type asipiration num_doors  \
# 0            3               NaN  alfa-romero       gas         std       two
# 1            3               NaN  alfa-romero       gas         std       two
# 2            1               NaN  alfa-romero       gas         std       two
# 3            2               164         audi       gas         std      four
# 4            2               164         audi       gas         std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...    engine_size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
cars['normalized_losses']=cars.normalized_losses(dtype='float')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-a8d62771a874> in <module>()
# ----> 1 cars['normalized_losses']=cars.normalized_losses(dtype='float')
#
# TypeError: 'Series' object is not callable

# %%
cars['normalized_losses']=pd.to_numeric(cars['normalized_losses'], errors='coerce')

# %% [raw]
# #'bore', 'stroke', 'horsepower', 'peak_rpm', 'price'

# %%
cars['stroke']=pd.to_numeric(cars['stroke'], errors='coerce')

# %%
cars['horsepower']=pd.to_numeric(cars['horsepower'], errors='coerce')

# %%
cars['peak_rpm']=pd.to_numeric(cars['peak_rpm'], errors='coerce')

# %%
cars['price']=pd.to_numeric(cars['price'], errors='coerce')

# %%
cars.dtypes
# Out:
# symbolizing            int64
# normalized_losses    float64
# make                  object
# fuel_type             object
# asipiration           object
# num_doors             object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_cylinders         object
# engine_size            int64
# fuel_system           object
# bore                  object
# stroke               float64
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
x=sum(cars['normalized_losses'].isnull())

# %%
print(x)
# Out:
# 41

# %%
print(cars)
# Out:
#      symbolizing  normalized_losses         make fuel_type asipiration  \
# 0              3                NaN  alfa-romero       gas         std
# 1              3                NaN  alfa-romero       gas         std
# 2              1                NaN  alfa-romero       gas         std
# 3              2              164.0         audi       gas         std
# 4              2              164.0         audi       gas         std
# 5              2                NaN         audi       gas         std
# 6              1              158.0         audi       gas         std
# 7              1                NaN         audi       gas         std
# 8              1              158.0         audi       gas       turbo
# 9              0                NaN         audi       gas       turbo
# 10             2              192.0          bmw       gas         std
# 11             0              192.0          bmw       gas         std
# ...

# %%
x=sum(cars.isnull(for dtype='float'))
print(x)
# Out:
#   File "<ipython-input-56-fc46edb0aedb>", line 1
#     x=sum(cars.isnull(for dtype='float'))
#                         ^
# SyntaxError: invalid syntax

# %%
cars.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-ffb9cd7b51a0> in <module>()
# ----> 1 cars.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
cars.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-9d96b391d464> in <module>()
# ----> 1 cars.dtype
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
cars.dtypes
# Out:
# symbolizing            int64
# normalized_losses    float64
# make                  object
# fuel_type             object
# asipiration           object
# num_doors             object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_cylinders         object
# engine_size            int64
# fuel_system           object
# bore                  object
# stroke               float64
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
num_cols=['symbolizing', 'wheel_base','length', 'width', 'height', 'curb_weight', 'engine_size', 'stroke', 'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price']
null_counts={}
for x in num_cols:
    y=sum(cars[x].isnull())
    null_counts[x]=y

# %%
print(null_counts)
# Out:
# {'symbolizing': 0, 'wheel_base': 0, 'length': 0, 'width': 0, 'height': 0, 'curb_weight': 0, 'engine_size': 0, 'stroke': 4, 'compression_ratio': 0, 'horsepower': 2, 'peak_rpm': 2, 'city_mpg': 0, 'highway_mpg': 0, 'price': 4}

# %%
cars=cars.dropna(axis=0)

# %%
cars.shape
# Out:
# (159, 26)

# %%
cars_wk=cars.copy()

# %%
cars_wk.head()
# Out:
#     symbolizing  normalized_losses  make fuel_type asipiration num_doors  \
# 3             2              164.0  audi       gas         std      four
# 4             2              164.0  audi       gas         std      four
# 6             1              158.0  audi       gas         std      four
# 8             1              158.0  audi       gas       turbo      four
# 10            2              192.0   bmw       gas         std       two
#
#    body_style drive_wheels engine_location  wheel_base   ...     engine_size  \
# 3       sedan          fwd           front        99.8   ...             109
# 4       sedan          4wd           front        99.4   ...             136
# 6       sedan          fwd           front       105.8   ...             136
# 8       sedan          fwd           front       105.8   ...             131
# 10      sedan          rwd           front       101.2   ...             108
#
# ...

# %%
cars_norm=(cars_wk-cars_wk.mean())/cars_wk.std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1466         try:
# -> 1467             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1468         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
cars_norm=cars_wk._get_numeric_data()

# %%
cars_norm.head()
# Out:
#     symbolizing  normalized_losses  wheel_base  length  width  height  \
# 3             2              164.0        99.8   176.6   66.2    54.3
# 4             2              164.0        99.4   176.6   66.4    54.3
# 6             1              158.0       105.8   192.7   71.4    55.7
# 8             1              158.0       105.8   192.7   71.4    55.9
# 10            2              192.0       101.2   176.8   64.8    54.3
#
#     curb_weight  engine_size  stroke  compression_ratio  horsepower  peak_rpm  \
# 3          2337          109     3.4               10.0       102.0    5500.0
# 4          2824          136     3.4                8.0       115.0    5500.0
# 6          2844          136     3.4                8.5       110.0    5500.0
# 8          3086          131     3.4                8.3       140.0    5500.0
# 10         2395          108     2.8                8.8       101.0    5800.0
#
#     city_mpg  highway_mpg    price
# 3         24           30  13950.0
# ...

# %%
cars_wk.head()
# Out:
#     symbolizing  normalized_losses  make fuel_type asipiration num_doors  \
# 3             2              164.0  audi       gas         std      four
# 4             2              164.0  audi       gas         std      four
# 6             1              158.0  audi       gas         std      four
# 8             1              158.0  audi       gas       turbo      four
# 10            2              192.0   bmw       gas         std       two
#
#    body_style drive_wheels engine_location  wheel_base   ...     engine_size  \
# 3       sedan          fwd           front        99.8   ...             109
# 4       sedan          4wd           front        99.4   ...             136
# 6       sedan          fwd           front       105.8   ...             136
# 8       sedan          fwd           front       105.8   ...             131
# 10      sedan          rwd           front       101.2   ...             108
#
# ...

# %%
num_cols=['symbolizing', 'wheel_base','length', 'width', 'height', 'curb_weight', 'engine_size', 'stroke', 'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price']
for i in num_cols:
    cars_wk[i]=cars_wk[i].apply(lambda x: (cars_wk[i]-np.mean(cars_wk[i]))/(np.std(cars_wk)))
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3755: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   return this.join(other, how=how, return_indexers=return_indexers)
